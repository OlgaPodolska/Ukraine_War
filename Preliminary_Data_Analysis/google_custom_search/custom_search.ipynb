# %%
import requests

# get the API KEY here: https://developers.google.com/custom-search/v1/overview
API_KEY = "AIzaSyAySPNzn6c5QffUbCLxWoGwFn5bwhbggBw"
# get your Search Engine ID on your CSE control panel
SEARCH_ENGINE_ID = "f70aeb575808e46a1"

# %%
# the search query you want
# For the 'query' parameter, we want to use the events listed in EventsUA.csv as our search parameters and compile a new csv for each. 
query = "Start Russian Invasion"
# using the first page
# page = 1
# constructing the URL
# doc: https://developers.google.com/custom-search/v1/using_rest
# calculating start, (page=2) => (start=11), (page=3) => (start=21)
# start = (page - 1) * 10 + 1
# url = f"https://www.googleapis.com/customsearch/v1?key={API_KEY}&cx={SEARCH_ENGINE_ID}&q={query}&start={start}"
url = f"https://www.googleapis.com/customsearch/v1?key={API_KEY}&cx={SEARCH_ENGINE_ID}&q={query}"

# %%
# make the API request
data = requests.get(url).json()

# %%
# get the result items
# search_items = data.get("items")
# # iterate over 10 results found
# for i, search_item in enumerate(search_items, start=1):
#     try:
#         long_description = search_item["pagemap"]["metatags"][0]["og:description"]
#     except KeyError:
#         long_description = "N/A"
#     # get the page title
#     title = search_item.get("title")
#     # page snippet
#     snippet = search_item.get("snippet")
#     # alternatively, you can get the HTML snippet (bolded keywords)
#     html_snippet = search_item.get("htmlSnippet")
#     # extract the page url
#     link = search_item.get("link")
#     # print the results
#     print("="*10, f"Result #{i+start-1}", "="*10)
#     print("Title:", title)
#     print("Description:", snippet)
#     print("Long description:", long_description)
#     print("URL:", link, "\n")
# Out:
# ========== Result #1 ==========
# Title: Timeline: The events leading up to Russia's invasion of Ukraine ...
# Description: Mar 1, 2022 ... Feb 28 (Reuters) - Russia launched a large-scale invasion of Ukraine on Feb. 24. Here is a timeline of Ukraine's fraught relationship with ...
# Long description: Russia launched a large-scale invasion of Ukraine on Feb. 24. Here is a timeline of Ukraine's fraught relationship with Moscow since it won independence in 1991 and the events that led to the current conflict.
# URL: https://www.reuters.com/world/europe/events-leading-up-russias-invasion-ukraine-2022-02-28/
#
# ========== Result #2 ==========
# Title: Blinken: Russian invasion of Ukraine could begin - CNNPolitics
# Description: Feb 11, 2022 ... The US and its allies have new intelligence that suggests Russia could launch an attack on Ukraine even before the end of the Olympics, multiple ...
# Long description: US Secretary of State Antony Blinken said Friday that a Russian invasion of Ukraine "could begin at any time," including during the Beijing Winter Olympics, and the United States continues "to see very troubling signs of Russian escalation, including new forces arriving at the Ukrainian border."
# URL: https://www.cnn.com/2022/02/11/politics/blinken-ukraine-russia-quad-melbourne/index.html
#
# ========== Result #3 ==========
# Title: Timeline of the Russian invasion of Ukraine: What we know so far ...
# Description: Feb 24, 2022 ... (CNN) Russia launched an invasion of Ukraine on Thursday, sending troops into the ex-Soviet nation from three fronts and firing missiles on ...
# Long description: Russia launched an invasion of Ukraine on Thursday, sending troops into the ex-Soviet nation from three fronts and firing missiles on several locations near the capital, Kyiv, in a broad attack that has drawn deep condemnation from world leaders.
# URL: https://www.cnn.com/2022/02/24/europe/ukraine-russia-attack-timeline-intl/index.html
#
# ========== Result #4 ==========
# Title: More than 1 million children fled Ukraine since start of Russian ...
# Description: Mar 9, 2022 ... More than 1 million children have fled Ukraine to neighboring countries in the less than two weeks since Russia started its invasion of ...
# Long description: More than 1 million children have fled Ukraine to neighboring countries in the less than two weeks since Russia started its invasion of Ukraine, the head of the United Nations Children's Fund (UNICEF) said on Wednesday.
# URL: https://www.reuters.com/world/europe/more-than-1-million-children-fled-ukraine-since-start-russian-invasion-unicef-2022-03-09/
#
# ========== Result #5 ==========
# Title: The Invasion of Ukraine: How Russia Attacked and What Happens ...
# Description: Feb 24, 2022 ... Explosions thundered in Ukrainian cities shortly after President Vladimir V. Putin declared the start of a “special military operation.”
# Long description: Explosions thundered in Ukrainian cities shortly after President Vladimir V. Putin declared the start of a “special military operation.”
# URL: https://www.nytimes.com/2022/02/24/world/europe/why-russia-attacked-ukraine.html
#
# ========== Result #6 ==========
# Title: Ukraine calls for no-fly zone to stop Russian bombardment | Reuters
# Description: Feb 28, 2022 ... The Russian invasion - the biggest assault on a European state since ... ally Belarus - a launch pad for invading Russian troops. read more.
# Long description: President Volodymyr Zelenskiy urged the West to consider a no-fly zone for Russian aircraft over Ukraine on Monday after Moscow bombarded the country's second largest city, drawing new sanctions by the United States and its allies.
# URL: https://www.reuters.com/world/europe/russias-isolation-deepens-ukraine-resists-invasion-2022-02-28/
#
# ========== Result #7 ==========
# Title: Over 7,000 Russian troops killed since start of invasion -Ukrainian ...
# Description: Mar 2, 2022 ... Over 7000 Russian servicemen have been killed since the start of Russia's invasion of Ukraine, while hundreds have been taken prisoner ...
# Long description: Over 7,000 Russian servicemen have been killed since the start of Russia's invasion of Ukraine, while hundreds have been taken prisoner including senior officers, a military adviser to Ukrainian President Volodymyr Zelenskiy said on Wednesday.
# URL: https://www.reuters.com/world/europe/over-7000-russian-troops-killed-since-start-invasion-ukrainian-official-2022-03-02/
#
# ========== Result #8 ==========
# Title: The Russian Invasion Begins - The New York Times
# Description: Feb 24, 2022 ... After months of escalating tensions, President Vladimir V. Putin of Russia took to state television on Thursday to declare the start of a ...
# Long description: In the hours before the assault and during the attack itself, we heard from our correspondents in the Ukrainian cities of Kyiv and Slovyansk, and in Moscow.
# URL: https://www.nytimes.com/2022/02/24/podcasts/the-daily/russian-invasion-ukraine-putin.html
#
# ========== Result #9 ==========
# Title: U.S. officials won't confirm reports on possible Russia invasion of ...
# Description: Feb 13, 2022 ... White House National Security Adviser Jake Sullivan repeated that a Russian invasion could begin any day and President Joe Biden has said he ...
# Long description: Senior U.S. officials on Sunday said they could not confirm reports that U.S. intelligence indicates that Russia is planning to invade Ukraine on Wednesday, but said they would try to prevent any "surprise attack" by sharing what they knew of Russia's plans.
# URL: https://www.reuters.com/world/europe/us-officials-wont-confirm-reports-possible-russia-invasion-ukraine-wednesday-2022-02-13/
#
# ========== Result #10 ==========
# Title: (70) 100,000 Ukrainian refugees have arrived since start of Russian ...
# Description: Feb 26, 2022 ... Around 100,000 people have entered Poland from Ukraine since the start of Russia's invasion of the country on Thursday, a Polish border ...
# Long description: Around 100,000 people have entered Poland from Ukraine since the start of Russia’s invasion of the country on Thursday, a Polish border guard said Saturday.
# URL: https://www.cnn.com/europe/live-news/ukraine-russia-news-02-26-22/h_efaa0d529edb3c122cc17b3968d6d211

# %%
# get the result items
search_items = data.get("items")
# import Pretty Print
from pprint import pprint
pprint(search_items)
# Out:
# [{'displayLink': 'www.reuters.com',
#   'formattedUrl': 'https://www.reuters.com/.../events-leading-up-russias-invasion-ukraine-2022- '
#                   '02-28/',
#   'htmlFormattedUrl': 'https://www.reuters.com/.../events-leading-up-<b>russias</b>-<b>invasion</b>-ukraine-2022- '
#                       '02-28/',
#   'htmlSnippet': 'Mar 1, 2022 <b>...</b> Feb 28 (Reuters) - <b>Russia</b> '
#                  'launched a large-scale <b>invasion</b> of Ukraine on Feb. '
#                  '24. Here is a timeline of Ukraine&#39;s fraught relationship '
#                  'with&nbsp;...',
#   'htmlTitle': 'Timeline: The events leading up to <b>Russia&#39;s '
#                'invasion</b> of Ukraine ...',
#   'kind': 'customsearch#result',
#   'link': 'https://www.reuters.com/world/europe/events-leading-up-russias-invasion-ukraine-2022-02-28/',
#   'pagemap': {'cse_image': [{'src': 'https://www.reuters.com/resizer/xKBIqZT6gpez8RbEJ8jO_d_qCec=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/W642SUPAGVKUTBVXN7RBVOSR4Q.jpg'}],
#               'cse_thumbnail': [{'height': '162',
#                                  'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRBy1Gj0qwh6yxi-CLK1w66ZPUK7wcuutMMJtifleQFh0mFRoWbT79F4ebZ',
#                                  'width': '311'}],
#               'metatags': [{'ad:template': 'article',
#                             'analytics:ad_layout': 'leaderboard, right rail, '
#                                                    'sponsored',
#                             'analytics:page_layout': 'regular-article',
#                             'analyticsattributes.topicchannel': 'World',
#                             'analyticsattributes.topicsubchannel': 'Europe',
#                             'apple-itunes-app': 'app-id=602660809',
#                             'article:author': 'Reuters',
#                             'article:content_tier': 'metered',
#                             'article:modified_time': '2022-03-01T09:26:48.441Z',
#                             'article:published_time': '2022-03-01T09:03:21Z',
#                             'article:section': 'Europe',
#                             'article:tag': 'MTPIX,FBOX,TMLN,CWP,DIP,EU,GEN,INTAG,NATO,NEWS1,POL,SECUR,TOPCMB,TOPNWS,WAR,CEEU,WEU,AMERS,US,EUROP,UA,RU,NASIA,NAMER,ASXPAC,CISC,EMRG,ASIA,EEU',
#                             'dcsext.channellist': 'World;',
#                             'dcsext.dartzone': '/4735792/reuters.com/world/europe/article',
#                             'fb:admins': '988502044532272',
#                             'fb:app_id': '988502044532272',
#                             'fb:pages': '114050161948682',
#                             'og:article:published_time': '2022-03-01T09:03:21Z',
#                             'og:description': 'Russia launched a large-scale '
#                                               'invasion of Ukraine on Feb. 24. '
#                                               "Here is a timeline of Ukraine's "
#                                               'fraught relationship with '
#                                               'Moscow since it won '
#                                               'independence in 1991 and the '
#                                               'events that led to the current '
#                                               'conflict.',
#                             'og:image': 'https://www.reuters.com/resizer/xKBIqZT6gpez8RbEJ8jO_d_qCec=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/W642SUPAGVKUTBVXN7RBVOSR4Q.jpg',
#                             'og:locale': 'en_US',
#                             'og:locale:alternate': 'jp_JP',
#                             'og:site_name': 'Reuters',
#                             'og:title': 'Timeline: The events leading up to '
#                                         "Russia's invasion of Ukraine",
#                             'og:type': 'article',
#                             'og:url': 'https://www.reuters.com/world/europe/events-leading-up-russias-invasion-ukraine-2022-02-28/',
#                             'twitter:card': 'summary_large_image',
#                             'twitter:creator': '@Reuters',
#                             'twitter:description': 'Russia launched a '
#                                                    'large-scale invasion of '
#                                                    'Ukraine on Feb. 24. Here '
#                                                    "is a timeline of Ukraine's "
#                                                    'fraught relationship with '
#                                                    'Moscow since it won '
#                                                    'independence in 1991 and '
#                                                    'the events that led to the '
#                                                    'current conflict.',
#                             'twitter:image': 'https://www.reuters.com/resizer/xKBIqZT6gpez8RbEJ8jO_d_qCec=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/W642SUPAGVKUTBVXN7RBVOSR4Q.jpg',
#                             'twitter:image:alt': 'People take cover as an '
#                                                  'air-raid siren sounds, near '
#                                                  'an apartment building '
#                                                  'damaged by recent shelling '
#                                                  'in Kyiv, Ukraine February '
#                                                  '26, 2022. REUTERS/Gleb '
#                                                  'Garanich/File Photo',
#                             'twitter:site': '@Reuters',
#                             'twitter:title': 'Timeline: The events leading up '
#                                              "to Russia's invasion of Ukraine",
#                             'viewport': 'width=device-width, '
#                                         'initial-scale=1'}]},
#   'snippet': 'Mar 1, 2022 ... Feb 28 (Reuters) - Russia launched a large-scale '
#              "invasion of Ukraine on Feb. 24. Here is a timeline of Ukraine's "
#              'fraught relationship with\xa0...',
#   'title': "Timeline: The events leading up to Russia's invasion of Ukraine "
#            '...'},
#  {'displayLink': 'www.cnn.com',
#   'formattedUrl': 'https://www.cnn.com/2022/02/11/politics/blinken...russia.../index.html',
#   'htmlFormattedUrl': 'https://www.cnn.com/2022/02/11/politics/blinken...<b>russia</b>.../index.html',
#   'htmlSnippet': 'Feb 11, 2022 <b>...</b> The US and its allies have new '
#                  'intelligence that suggests <b>Russia</b> could <b>launch</b> '
#                  'an attack on Ukraine even before the end of the Olympics, '
#                  'multiple&nbsp;...',
#   'htmlTitle': 'Blinken: <b>Russian invasion</b> of Ukraine could <b>begin</b> '
#                '- CNNPolitics',
#   'kind': 'customsearch#result',
#   'link': 'https://www.cnn.com/2022/02/11/politics/blinken-ukraine-russia-quad-melbourne/index.html',
#   'pagemap': {'cse_image': [{'height': '168',
#                              'src': 'https://cdn.cnn.com/cnnnext/dam/assets/220211011958-02-blinken-quad-02112022-super-tease.jpg',
#                              'type': '1',
#                              'width': '299'}],
#               'metatags': [{'article:author': 'https://www.facebook.com/jimsciuttocnn',
#                             'article:content-tier': 'free',
#                             'article:opinion': 'false',
#                             'author': 'Jennifer Hansler, Kylie Atwood, Natasha '
#                                       'Bertrand, Katie Bo Lillis and Jim '
#                                       'Sciutto, CNN',
#                             'fb:app_id': '80401312489',
#                             'fb:pages': '5550296508,18793419640',
#                             'lastmod': '2022-02-11T17:55:57Z',
#                             'og:description': 'US Secretary of State Antony '
#                                               'Blinken said Friday that a '
#                                               'Russian invasion of Ukraine '
#                                               '"could begin at any time," '
#                                               'including during the Beijing '
#                                               'Winter Olympics, and the United '
#                                               'States continues "to see very '
#                                               'troubling signs of Russian '
#                                               'escalation, including new '
#                                               'forces arriving at the '
#                                               'Ukrainian border."',
#                             'og:image': 'https://cdn.cnn.com/cnnnext/dam/assets/220211011958-02-blinken-quad-02112022-super-tease.jpg',
#                             'og:image:height': '619',
#                             'og:image:width': '1100',
#                             'og:pubdate': '2022-02-11T11:53:22Z',
#                             'og:site_name': 'CNN',
#                             'og:title': 'Blinken: Russian invasion of Ukraine '
#                                         "'could begin at any time'",
#                             'og:type': 'article',
#                             'og:url': 'https://www.cnn.com/2022/02/11/politics/blinken-ukraine-russia-quad-melbourne/index.html',
#                             'pubdate': '2022-02-11T11:53:22Z',
#                             'referrer': 'unsafe-url',
#                             'section': 'politics',
#                             'template-top': 'politics,art-vid-col,col-politics-of-the-day',
#                             'theme-color': '#000000',
#                             'thumbnail': 'https://cdn.cnn.com/cnnnext/dam/assets/220211011958-02-blinken-quad-02112022-super-tease.jpg',
#                             'twitter:card': 'summary_large_image',
#                             'twitter:description': 'US Secretary of State '
#                                                    'Antony Blinken said Friday '
#                                                    'that a Russian invasion of '
#                                                    'Ukraine "could begin at '
#                                                    'any time," including '
#                                                    'during the Beijing Winter '
#                                                    'Olympics, and the United '
#                                                    'States continues "to see '
#                                                    'very troubling signs of '
#                                                    'Russian escalation, '
#                                                    'including new forces '
#                                                    'arriving at the Ukrainian '
#                                                    'border."',
#                             'twitter:image': 'https://cdn.cnn.com/cnnnext/dam/assets/220211011958-02-blinken-quad-02112022-super-tease.jpg',
#                             'twitter:title': 'Blinken: Russian invasion of '
#                                              "Ukraine 'could begin at any "
#                                              "time'",
#                             'viewport': 'width=device-width, '
#                                         'initial-scale=1.0, minimum-scale=1.0',
#                             'vr:canonical': 'https://www.cnn.com/2022/02/11/politics/blinken-ukraine-russia-quad-melbourne/index.html'}],
#               'newsarticle': [{'alternativeheadline': 'Blinken: Russian '
#                                                       'invasion of Ukraine '
#                                                       "'could begin at any "
#                                                       "time'",
#                                'articlebody': 'Melbourne, Australia (CNN)US '
#                                               'Secretary of State Antony '
#                                               'Blinken said Friday that a '
#                                               'Russian invasion of Ukraine '
#                                               '"could begin at any time," '
#                                               'including during the Beijing '
#                                               'Winter Olympics, and the...',
#                                'articlesection': 'politics',
#                                'author': 'Jennifer Hansler, Kylie Atwood, '
#                                          'Natasha Bertrand, Katie Bo Lillis '
#                                          'and Jim Sciutto, CNN',
#                                'datecreated': '2022-02-11T11:53:22Z',
#                                'datemodified': '2022-02-11T17:55:57Z',
#                                'datepublished': '2022-02-11T11:53:22Z',
#                                'description': 'US Secretary of State Antony '
#                                               'Blinken said Friday that a '
#                                               'Russian invasion of Ukraine '
#                                               '"could begin at any time," '
#                                               'including during the Beijing '
#                                               'Winter Olympics, and the United '
#                                               'States continues...',
#                                'headline': 'Blinken: Russian invasion of '
#                                            'Ukraine could begin - CNNPolitics',
#                                'image': 'https://cdn.cnn.com/cnnnext/dam/assets/220211011958-02-blinken-quad-02112022-super-tease.jpg',
#                                'ispartof': 'politics',
#                                'keywords': 'politics, Blinken: Russian '
#                                            'invasion of Ukraine could begin - '
#                                            'CNNPolitics',
#                                'thumbnailurl': 'https://cdn.cnn.com/cnnnext/dam/assets/220211011958-02-blinken-quad-02112022-super-tease.jpg',
#                                'url': 'https://www.cnn.com/2022/02/11/politics/blinken-ukraine-russia-quad-melbourne/index.html'}],
#               'thumbnail': [{'src': 'https://cdn.cnn.com/cnnnext/dam/assets/220211011958-02-blinken-quad-02112022-super-tease.jpg'}]},
#   'snippet': 'Feb 11, 2022 ... The US and its allies have new intelligence '
#              'that suggests Russia could launch an attack on Ukraine even '
#              'before the end of the Olympics, multiple\xa0...',
#   'title': 'Blinken: Russian invasion of Ukraine could begin - CNNPolitics'},
#  {'displayLink': 'www.cnn.com',
#   'formattedUrl': 'https://www.cnn.com/2022/02/24/europe/ukraine-russia.../index.html',
#   'htmlFormattedUrl': 'https://www.cnn.com/2022/02/24/europe/ukraine-<b>russia</b>.../index.html',
#   'htmlSnippet': 'Feb 24, 2022 <b>...</b> (CNN) <b>Russia</b> launched an '
#                  '<b>invasion</b> of Ukraine on Thursday, sending troops into '
#                  'the ex-<b>Soviet</b> nation from three fronts and firing '
#                  'missiles on&nbsp;...',
#   'htmlTitle': 'Timeline of the <b>Russian invasion</b> of Ukraine: What we '
#                'know so far ...',
#   'kind': 'customsearch#result',
#   'link': 'https://www.cnn.com/2022/02/24/europe/ukraine-russia-attack-timeline-intl/index.html',
#   'pagemap': {'cse_image': [{'height': '168',
#                              'src': 'https://cdn.cnn.com/cnnnext/dam/assets/220224015519-08-ukraine-0224-super-tease.jpg',
#                              'type': '1',
#                              'width': '299'}],
#               'metatags': [{'article:author': 'https://www.facebook.com/paul.p.murphy00',
#                             'article:content-tier': 'free',
#                             'article:opinion': 'false',
#                             'author': 'Tim Lister, Tara John and Paul P. '
#                                       'Murphy, CNN',
#                             'fb:app_id': '80401312489',
#                             'fb:pages': '5550296508,18793419640',
#                             'lastmod': '2022-02-24T16:42:43Z',
#                             'og:description': 'Russia launched an invasion of '
#                                               'Ukraine on Thursday, sending '
#                                               'troops into the ex-Soviet '
#                                               'nation from three fronts and '
#                                               'firing missiles on several '
#                                               'locations near the capital, '
#                                               'Kyiv, in a broad attack that '
#                                               'has drawn deep condemnation '
#                                               'from world leaders.',
#                             'og:image': 'https://cdn.cnn.com/cnnnext/dam/assets/220224015519-08-ukraine-0224-super-tease.jpg',
#                             'og:image:height': '619',
#                             'og:image:width': '1100',
#                             'og:pubdate': '2022-02-24T10:42:46Z',
#                             'og:site_name': 'CNN',
#                             'og:title': "Here's what we know about how "
#                                         "Russia's invasion of Ukraine unfolded",
#                             'og:type': 'article',
#                             'og:url': 'https://www.cnn.com/2022/02/24/europe/ukraine-russia-attack-timeline-intl/index.html',
#                             'pubdate': '2022-02-24T10:42:46Z',
#                             'referrer': 'unsafe-url',
#                             'section': 'europe',
#                             'template-top': 'intl_regions,europe,news,art-vid',
#                             'theme-color': '#000000',
#                             'thumbnail': 'https://cdn.cnn.com/cnnnext/dam/assets/220224015519-08-ukraine-0224-super-tease.jpg',
#                             'twitter:card': 'summary_large_image',
#                             'twitter:description': 'Russia launched an '
#                                                    'invasion of Ukraine on '
#                                                    'Thursday, sending troops '
#                                                    'into the ex-Soviet nation '
#                                                    'from three fronts and '
#                                                    'firing missiles on several '
#                                                    'locations near the '
#                                                    'capital, Kyiv, in a broad '
#                                                    'attack that has drawn deep '
#                                                    'condemnation from world '
#                                                    'leaders.',
#                             'twitter:image': 'https://cdn.cnn.com/cnnnext/dam/assets/220224015519-08-ukraine-0224-super-tease.jpg',
#                             'twitter:title': "Here's what we know about how "
#                                              "Russia's invasion of Ukraine "
#                                              'unfolded',
#                             'viewport': 'width=device-width, '
#                                         'initial-scale=1.0, minimum-scale=1.0',
#                             'vr:canonical': 'https://www.cnn.com/2022/02/24/europe/ukraine-russia-attack-timeline-intl/index.html'}],
#               'newsarticle': [{'alternativeheadline': "Here's what we know "
#                                                       "about how Russia's "
#                                                       'invasion of Ukraine '
#                                                       'unfolded',
#                                'articlebody': '(CNN)Russia launched an '
#                                               'invasion of Ukraine on '
#                                               'Thursday, sending troops into '
#                                               'the ex-Soviet nation from three '
#                                               'fronts and firing missiles on '
#                                               'several locations near the '
#                                               'capital, Kyiv, in a broad...',
#                                'articlesection': 'europe',
#                                'author': 'Tim Lister, Tara John and Paul P. '
#                                          'Murphy, CNN',
#                                'datecreated': '2022-02-24T10:42:46Z',
#                                'datemodified': '2022-02-24T16:42:43Z',
#                                'datepublished': '2022-02-24T10:42:46Z',
#                                'description': 'Russia launched an invasion of '
#                                               'Ukraine on Thursday, sending '
#                                               'troops into the ex-Soviet '
#                                               'nation from three fronts and '
#                                               'firing missiles on several '
#                                               'locations near the capital, '
#                                               'Kyiv, in a broad attack...',
#                                'headline': 'Timeline of the Russian invasion '
#                                            'of Ukraine: What we know so far - '
#                                            'CNN',
#                                'image': 'https://cdn.cnn.com/cnnnext/dam/assets/220224015519-08-ukraine-0224-super-tease.jpg',
#                                'ispartof': 'news',
#                                'keywords': 'europe, Timeline of the Russian '
#                                            'invasion of Ukraine: What we know '
#                                            'so far - CNN',
#                                'thumbnailurl': 'https://cdn.cnn.com/cnnnext/dam/assets/220224015519-08-ukraine-0224-super-tease.jpg',
#                                'url': 'https://www.cnn.com/2022/02/24/europe/ukraine-russia-attack-timeline-intl/index.html'}],
#               'thumbnail': [{'src': 'https://cdn.cnn.com/cnnnext/dam/assets/220224015519-08-ukraine-0224-super-tease.jpg'}]},
#   'snippet': 'Feb 24, 2022 ... (CNN) Russia launched an invasion of Ukraine on '
#              'Thursday, sending troops into the ex-Soviet nation from three '
#              'fronts and firing missiles on\xa0...',
#   'title': 'Timeline of the Russian invasion of Ukraine: What we know so far '
#            '...'},
#  {'displayLink': 'www.reuters.com',
#   'formattedUrl': 'https://www.reuters.com/.../more-than-1-million-children-fled-ukraine-since- '
#                   'start-russian-invasion-unicef-2022-03-09/',
#   'htmlFormattedUrl': 'https://www.reuters.com/.../more-than-1-million-children-fled-ukraine-since- '
#                       '<b>start</b>-<b>russian</b>-<b>invasion</b>-unicef-2022-03-09/',
#   'htmlSnippet': 'Mar 9, 2022 <b>...</b> More than 1 million children have '
#                  'fled Ukraine to neighboring countries in the less than two '
#                  'weeks since <b>Russia started</b> its <b>invasion</b> '
#                  'of&nbsp;...',
#   'htmlTitle': 'More than 1 million children fled Ukraine since <b>start</b> '
#                'of <b>Russian</b> ...',
#   'kind': 'customsearch#result',
#   'link': 'https://www.reuters.com/world/europe/more-than-1-million-children-fled-ukraine-since-start-russian-invasion-unicef-2022-03-09/',
#   'pagemap': {'cse_image': [{'src': 'https://www.reuters.com/resizer/iLIdGjxUvLahkwl2kvTgbhV7TGQ=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/7AC76QLAGNK3HHPA7EJK6S4P3A.jpg'}],
#               'cse_thumbnail': [{'height': '162',
#                                  'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcQgZEWBIXn6U3AMGfxpMMltjuvFU48J53M5VY9kLS3qopiEAYLMl0gREHM',
#                                  'width': '311'}],
#               'metatags': [{'ad:template': 'article',
#                             'analytics:ad_layout': 'leaderboard, right rail, '
#                                                    'sponsored',
#                             'analytics:page_layout': 'regular-article',
#                             'analyticsattributes.topicchannel': 'World',
#                             'analyticsattributes.topicsubchannel': 'Europe',
#                             'apple-itunes-app': 'app-id=602660809',
#                             'article:author': 'Reuters',
#                             'article:content_tier': 'metered',
#                             'article:modified_time': '2022-03-09T21:38:50.441Z',
#                             'article:published_time': '2022-03-09T21:37:34Z',
#                             'article:section': 'Europe',
#                             'article:tag': 'CHLD,CWP,GEN,INTAG,POL,SOCI,UN1,UNICEF,WAR,CEEU,AMERS,US,EUROP,UA,RU,NASIA,NAMER,ASXPAC,CISC,EMRG,ASIA',
#                             'dcsext.channellist': 'World;',
#                             'dcsext.dartzone': '/4735792/reuters.com/world/europe/article',
#                             'fb:admins': '988502044532272',
#                             'fb:app_id': '988502044532272',
#                             'fb:pages': '114050161948682',
#                             'og:article:published_time': '2022-03-09T21:37:34Z',
#                             'og:description': 'More than 1 million children '
#                                               'have fled Ukraine to '
#                                               'neighboring countries in the '
#                                               'less than two weeks since '
#                                               'Russia started its invasion of '
#                                               'Ukraine, the head of the United '
#                                               "Nations Children's Fund "
#                                               '(UNICEF) said on Wednesday.',
#                             'og:image': 'https://www.reuters.com/resizer/iLIdGjxUvLahkwl2kvTgbhV7TGQ=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/7AC76QLAGNK3HHPA7EJK6S4P3A.jpg',
#                             'og:locale': 'en_US',
#                             'og:locale:alternate': 'jp_JP',
#                             'og:site_name': 'Reuters',
#                             'og:title': 'More than 1 million children fled '
#                                         'Ukraine since start of Russian '
#                                         'invasion -UNICEF',
#                             'og:type': 'article',
#                             'og:url': 'https://www.reuters.com/world/europe/more-than-1-million-children-fled-ukraine-since-start-russian-invasion-unicef-2022-03-09/',
#                             'twitter:card': 'summary_large_image',
#                             'twitter:creator': '@Reuters',
#                             'twitter:description': 'More than 1 million '
#                                                    'children have fled Ukraine '
#                                                    'to neighboring countries '
#                                                    'in the less than two weeks '
#                                                    'since Russia started its '
#                                                    'invasion of Ukraine, the '
#                                                    'head of the United Nations '
#                                                    "Children's Fund (UNICEF) "
#                                                    'said on Wednesday.',
#                             'twitter:image': 'https://www.reuters.com/resizer/iLIdGjxUvLahkwl2kvTgbhV7TGQ=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/7AC76QLAGNK3HHPA7EJK6S4P3A.jpg',
#                             'twitter:image:alt': 'Children look out from an '
#                                                  'evacuation train from Kyiv '
#                                                  'to Lviv as they say goodbye '
#                                                  'to their father at Kyiv '
#                                                  'central train station in '
#                                                  'central Kyiv, Ukraine March '
#                                                  '3, 2022. REUTERS/Gleb '
#                                                  'Garanich/File Photo',
#                             'twitter:site': '@Reuters',
#                             'twitter:title': 'More than 1 million children '
#                                              'fled Ukraine since start of '
#                                              'Russian invasion -UNICEF',
#                             'viewport': 'width=device-width, '
#                                         'initial-scale=1'}]},
#   'snippet': 'Mar 9, 2022 ... More than 1 million children have fled Ukraine '
#              'to neighboring countries in the less than two weeks since Russia '
#              'started its invasion of\xa0...',
#   'title': 'More than 1 million children fled Ukraine since start of Russian '
#            '...'},
#  {'displayLink': 'www.nytimes.com',
#   'formattedUrl': 'https://www.nytimes.com/2022/02/24/.../why-russia-attacked-ukraine.html',
#   'htmlFormattedUrl': 'https://www.nytimes.com/2022/02/24/.../why-<b>russia</b>-attacked-ukraine.html',
#   'htmlSnippet': 'Feb 24, 2022 <b>...</b> Explosions thundered in Ukrainian '
#                  'cities shortly after President Vladimir V. Putin declared '
#                  'the <b>start</b> of a “special military operation.”',
#   'htmlTitle': 'The <b>Invasion</b> of Ukraine: How <b>Russia</b> Attacked and '
#                'What Happens ...',
#   'kind': 'customsearch#result',
#   'link': 'https://www.nytimes.com/2022/02/24/world/europe/why-russia-attacked-ukraine.html',
#   'pagemap': {'cse_image': [{'src': 'https://static01.nyt.com/images/2022/02/24/world/24ukraine-what-happened01/24ukraine-what-happened01-facebookJumbo.jpg'}],
#               'cse_thumbnail': [{'height': '162',
#                                  'src': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcSxMBBG3Nl7OTbfg_8H2Zht1KkY2kZ6L2eI1remUYPBqAr0vuUdFTRL7R08',
#                                  'width': '310'}],
#               'metatags': [{'al:android:app_name': 'NYTimes',
#                             'al:android:package': 'com.nytimes.android',
#                             'al:android:url': 'nyt://article/a0cd5499-2ca4-52c0-8527-afdb8c29477c',
#                             'article:content_tier': 'metered',
#                             'article:modified_time': '2022-02-24T19:30:47.000Z',
#                             'article:opinion': 'false',
#                             'article:published_time': '2022-02-24T09:46:00.000Z',
#                             'article:section': 'World',
#                             'article:tag': 'Russian Invasion of Ukraine (2022)',
#                             'articleid': '100000008225423',
#                             'byl': 'By Austin Ramzy',
#                             'cg': 'world',
#                             'image': 'https://static01.nyt.com/images/2022/02/24/world/24ukraine-what-happened01/24ukraine-what-happened01-facebookJumbo.jpg',
#                             'msapplication-starturl': 'https://www.nytimes.com',
#                             'news_keywords': 'Russian Invasion of Ukraine '
#                                              '(2022),Military,Politics,War;Armed '
#                                              'Conflicts,US Foreign '
#                                              'Policy,EU,NATO,UN Security '
#                                              'Council,UN,Joe Biden,Volodymyr '
#                                              'Zelensky,Eastern '
#                                              'Europe,Russia,Ukraine,Europe,Vladimir '
#                                              'Putin',
#                             'nyt_uri': 'nyt://article/a0cd5499-2ca4-52c0-8527-afdb8c29477c',
#                             'og:description': 'Explosions thundered in '
#                                               'Ukrainian cities shortly after '
#                                               'President Vladimir V. Putin '
#                                               'declared the start of a '
#                                               '“special military operation.”',
#                             'og:image': 'https://static01.nyt.com/images/2022/02/24/world/24ukraine-what-happened01/24ukraine-what-happened01-facebookJumbo.jpg',
#                             'og:image:alt': 'A building in eastern Ukraine on '
#                                             'Thursday after Russian forces '
#                                             'bombed the area.',
#                             'og:title': 'The Invasion of Ukraine: How Russia '
#                                         'Attacked and What Happens Next',
#                             'og:type': 'article',
#                             'og:url': 'https://www.nytimes.com/2022/02/24/world/europe/why-russia-attacked-ukraine.html',
#                             'pdate': '20220224',
#                             'pst': 'News',
#                             'pt': 'article',
#                             'pubp_event_id': 'pubp://event/c2243ed0e3ac47dca85d0253de3f62cd',
#                             'scg': 'europe',
#                             'twitter:app:name:googleplay': 'NYTimes',
#                             'twitter:card': 'summary_large_image',
#                             'twitter:description': 'Explosions thundered in '
#                                                    'Ukrainian cities shortly '
#                                                    'after President Vladimir '
#                                                    'V. Putin declared the '
#                                                    'start of a “special '
#                                                    'military operation.”',
#                             'twitter:image': 'https://static01.nyt.com/images/2022/02/24/world/24ukraine-what-happened01/24ukraine-what-happened01-videoSixteenByNine3000.jpg',
#                             'twitter:image:alt': 'A building in eastern '
#                                                  'Ukraine on Thursday after '
#                                                  'Russian forces bombed the '
#                                                  'area.',
#                             'twitter:title': 'The Invasion of Ukraine: How '
#                                              'Russia Attacked and What Happens '
#                                              'Next',
#                             'twitter:url': 'https://www.nytimes.com/2022/02/24/world/europe/why-russia-attacked-ukraine.html',
#                             'url': 'https://www.nytimes.com/2022/02/24/world/europe/why-russia-attacked-ukraine.html'}]},
#   'snippet': 'Feb 24, 2022 ... Explosions thundered in Ukrainian cities '
#              'shortly after President Vladimir V. Putin declared the start of '
#              'a “special military operation.”',
#   'title': 'The Invasion of Ukraine: How Russia Attacked and What Happens ...'},
#  {'displayLink': 'www.reuters.com',
#   'formattedUrl': 'https://www.reuters.com/.../russias-isolation-deepens-ukraine-resists-invasion- '
#                   '2022-02-28/',
#   'htmlFormattedUrl': 'https://www.reuters.com/.../<b>russias</b>-isolation-deepens-ukraine-resists-<b>invasion</b>- '
#                       '2022-02-28/',
#   'htmlSnippet': 'Feb 28, 2022 <b>...</b> The <b>Russian invasion</b> - the '
#                  'biggest assault on a European state since ... ally Belarus - '
#                  'a <b>launch</b> pad for <b>invading Russian</b> troops. read '
#                  'more.',
#   'htmlTitle': 'Ukraine calls for no-fly zone to stop <b>Russian</b> '
#                'bombardment | Reuters',
#   'kind': 'customsearch#result',
#   'link': 'https://www.reuters.com/world/europe/russias-isolation-deepens-ukraine-resists-invasion-2022-02-28/',
#   'pagemap': {'cse_image': [{'src': 'https://www.reuters.com/resizer/NuAyJZT7p6_tJ_qOzub6RlcN1Qc=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/GCOWQP6MQJOVLOJ6X3EXITXSKY.jpg'}],
#               'cse_thumbnail': [{'height': '162',
#                                  'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQpHsflaF_dL1nhOENZ2vLx6Nf5-d-2fjWfuJJY1D-y_fu1gQvJmVa97Co',
#                                  'width': '311'}],
#               'metatags': [{'ad:template': 'article',
#                             'analytics:ad_layout': 'leaderboard, right rail, '
#                                                    'sponsored',
#                             'analytics:page_layout': 'regular-article',
#                             'analyticsattributes.topicchannel': 'World',
#                             'analyticsattributes.topicsubchannel': 'Europe',
#                             'apple-itunes-app': 'app-id=602660809',
#                             'article:author': 'Reuters',
#                             'article:content_tier': 'metered',
#                             'article:modified_time': '2022-03-01T03:04:21.074Z',
#                             'article:published_time': '2022-03-01T03:03:39Z',
#                             'article:section': 'Europe',
#                             'article:tag': 'M:2DZ,MTVID,MTGFX,MTPIX,AID,AIRL,AIRL1,AIRS08,BISV,BISV08,BNKS,BNKS1,BSVC,CEN,CIV,CMPNY,COM,CWP,DEF,DIP,DRIL,ENER,ENFF,ENG,ENQSVC,ENR,EU,EXPRO,FIN,FINS,FINS08,FRX,GEN,HRGT,IMM,INDS,INDS08,INTAG,MCE,NATO,NEWS1,NGS,NRG,NUCL,OILG,OILI,OILI08,POL,PSSNGR,PUBL,RACR,REFI,REFI1,SECUR,SOCI,TPT,TRAN,TRD,UK,UN1,WAR,WASH,GB,CEEU,WEU,AMERS,US,EUROP,UA,RU,NASIA,NAMER,ASXPAC,CISC,EMRG,ASIA,ECON,TOPNWS,ITSE,ITSE08,NETSV,SOCMED,SWIT,TECH,TECH08,TMT,NUCPWR,PWR,PWRGEN,NUC,INT,PXP,CW,CARIBN,PL,NL,LATAM,EEU',
#                             'dcsext.channellist': 'World;U.S. '
#                                                   'Markets;Commodities;Currencies;Middle '
#                                                   'East;United '
#                                                   'Kingdom;European '
#                                                   'Markets;Asian Markets',
#                             'dcsext.dartzone': '/4735792/reuters.com/world/europe/article',
#                             'fb:admins': '988502044532272',
#                             'fb:app_id': '988502044532272',
#                             'fb:pages': '114050161948682',
#                             'og:article:published_time': '2022-03-01T03:03:39Z',
#                             'og:description': 'President Volodymyr Zelenskiy '
#                                               'urged the West to consider a '
#                                               'no-fly zone for Russian '
#                                               'aircraft over Ukraine on Monday '
#                                               'after Moscow bombarded the '
#                                               "country's second largest city, "
#                                               'drawing new sanctions by the '
#                                               'United States and its allies.',
#                             'og:image': 'https://www.reuters.com/resizer/NuAyJZT7p6_tJ_qOzub6RlcN1Qc=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/GCOWQP6MQJOVLOJ6X3EXITXSKY.jpg',
#                             'og:locale': 'en_US',
#                             'og:locale:alternate': 'jp_JP',
#                             'og:site_name': 'Reuters',
#                             'og:title': 'Ukraine calls for no-fly zone to stop '
#                                         'Russian bombardment',
#                             'og:type': 'article',
#                             'og:url': 'https://www.reuters.com/world/europe/russias-isolation-deepens-ukraine-resists-invasion-2022-02-28/',
#                             'twitter:card': 'summary_large_image',
#                             'twitter:creator': '@Reuters',
#                             'twitter:description': 'President Volodymyr '
#                                                    'Zelenskiy urged the West '
#                                                    'to consider a no-fly zone '
#                                                    'for Russian aircraft over '
#                                                    'Ukraine on Monday after '
#                                                    'Moscow bombarded the '
#                                                    "country's second largest "
#                                                    'city, drawing new '
#                                                    'sanctions by the United '
#                                                    'States and its allies.',
#                             'twitter:image': 'https://www.reuters.com/resizer/NuAyJZT7p6_tJ_qOzub6RlcN1Qc=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/GCOWQP6MQJOVLOJ6X3EXITXSKY.jpg',
#                             'twitter:image:alt': 'Ukrainian service members '
#                                                  'are seen after Russia '
#                                                  'launched a massive military '
#                                                  'operation against Ukraine, '
#                                                  'at a check point in the city '
#                                                  'of Zhytomyr, Ukraine '
#                                                  'February 27, 2022.  '
#                                                  'REUTERS/Viacheslav Ratynskyi',
#                             'twitter:site': '@Reuters',
#                             'twitter:title': 'Ukraine calls for no-fly zone to '
#                                              'stop Russian bombardment',
#                             'viewport': 'width=device-width, '
#                                         'initial-scale=1'}]},
#   'snippet': 'Feb 28, 2022 ... The Russian invasion - the biggest assault on a '
#              'European state since ... ally Belarus - a launch pad for '
#              'invading Russian troops. read more.',
#   'title': 'Ukraine calls for no-fly zone to stop Russian bombardment | '
#            'Reuters'},
#  {'displayLink': 'www.reuters.com',
#   'formattedUrl': 'https://www.reuters.com/.../over-7000-russian-troops-killed-since-start- '
#                   'invasion-ukrainian-official-2022-03-02/',
#   'htmlFormattedUrl': 'https://www.reuters.com/.../over-7000-<b>russian</b>-troops-killed-since-<b>start</b>- '
#                       '<b>invasion</b>-ukrainian-official-2022-03-02/',
#   'htmlSnippet': 'Mar 2, 2022 <b>...</b> Over 7000 <b>Russian</b> servicemen '
#                  'have been killed since the <b>start</b> of <b>Russia&#39;s '
#                  'invasion</b> of Ukraine, while hundreds have been taken '
#                  'prisoner&nbsp;...',
#   'htmlTitle': 'Over 7,000 <b>Russian</b> troops killed since <b>start</b> of '
#                '<b>invasion</b> -Ukrainian ...',
#   'kind': 'customsearch#result',
#   'link': 'https://www.reuters.com/world/europe/over-7000-russian-troops-killed-since-start-invasion-ukrainian-official-2022-03-02/',
#   'pagemap': {'cse_image': [{'src': 'https://www.reuters.com/resizer/k6iK0q1eu47TxUBYMKZH4hMb4vk=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/B7AA4PJ7ABID5O7AHEOA7AUHLQ.jpg'}],
#               'cse_thumbnail': [{'height': '162',
#                                  'src': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcTBPHObD7H9eYDq5VYui-LshlB8DFGxAlWJqrzcRGkr5eso2OZ70T7loA4E',
#                                  'width': '311'}],
#               'metatags': [{'ad:template': 'article',
#                             'analytics:ad_layout': 'leaderboard, right rail, '
#                                                    'sponsored',
#                             'analytics:page_layout': 'regular-article',
#                             'analyticsattributes.topicchannel': 'World',
#                             'analyticsattributes.topicsubchannel': 'Europe',
#                             'apple-itunes-app': 'app-id=602660809',
#                             'article:author': 'Reuters',
#                             'article:content_tier': 'metered',
#                             'article:modified_time': '2022-03-02T17:59:03.923Z',
#                             'article:published_time': '2022-03-02T17:58:37Z',
#                             'article:section': 'Europe',
#                             'article:tag': 'M:1QD,BRU,CWP,DEF,EU,GEN,INTAG,NATO,NEWS1,POL,SECUR,SOCI,VIO,WAR,WASH,CEEU,AMERS,US,EUROP,UA,RU,NASIA,NAMER,ASXPAC,CISC,EMRG,ASIA,M:2CM,M:2CN,M:2CP,M:2CQ,M:2CR,M:2CS,M:2CT,M:2CU,M:2CV,M:2D1',
#                             'dcsext.channellist': 'World;',
#                             'dcsext.dartzone': '/4735792/reuters.com/world/europe/article',
#                             'fb:admins': '988502044532272',
#                             'fb:app_id': '988502044532272',
#                             'fb:pages': '114050161948682',
#                             'og:article:published_time': '2022-03-02T17:58:37Z',
#                             'og:description': 'Over 7,000 Russian servicemen '
#                                               'have been killed since the '
#                                               "start of Russia's invasion of "
#                                               'Ukraine, while hundreds have '
#                                               'been taken prisoner including '
#                                               'senior officers, a military '
#                                               'adviser to Ukrainian President '
#                                               'Volodymyr Zelenskiy said on '
#                                               'Wednesday.',
#                             'og:image': 'https://www.reuters.com/resizer/k6iK0q1eu47TxUBYMKZH4hMb4vk=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/B7AA4PJ7ABID5O7AHEOA7AUHLQ.jpg',
#                             'og:locale': 'en_US',
#                             'og:locale:alternate': 'jp_JP',
#                             'og:site_name': 'Reuters',
#                             'og:title': 'Over 7,000 Russian troops killed '
#                                         'since start of invasion -Ukrainian '
#                                         'official',
#                             'og:type': 'article',
#                             'og:url': 'https://www.reuters.com/world/europe/over-7000-russian-troops-killed-since-start-invasion-ukrainian-official-2022-03-02/',
#                             'twitter:card': 'summary_large_image',
#                             'twitter:creator': '@Reuters',
#                             'twitter:description': 'Over 7,000 Russian '
#                                                    'servicemen have been '
#                                                    'killed since the start of '
#                                                    "Russia's invasion of "
#                                                    'Ukraine, while hundreds '
#                                                    'have been taken prisoner '
#                                                    'including senior officers, '
#                                                    'a military adviser to '
#                                                    'Ukrainian President '
#                                                    'Volodymyr Zelenskiy said '
#                                                    'on Wednesday.',
#                             'twitter:image': 'https://www.reuters.com/resizer/k6iK0q1eu47TxUBYMKZH4hMb4vk=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/B7AA4PJ7ABID5O7AHEOA7AUHLQ.jpg',
# ...
#                                                    'assault and during the '
#                                                    'attack itself, we heard '
#                                                    'from our correspondents in '
#                                                    'the Ukrainian cities of '
#                                                    'Kyiv and Slovyansk, and in '
#                                                    'Moscow.',
#                             'twitter:image': 'https://static01.nyt.com/images/2022/02/24/world/24daily-russia-invasion/24daily-russia-invasion-videoSixteenByNine3000.jpg',
#                             'twitter:image:alt': 'Taking refuge in a metro '
#                                                  'station in Kyiv, the capital '
#                                                  'of Ukraine, after sirens '
#                                                  'sounded on Thursday.',
#                             'twitter:title': 'The Russian Invasion Begins',
#                             'twitter:url': 'https://www.nytimes.com/2022/02/24/podcasts/the-daily/russian-invasion-ukraine-putin.html',
#                             'url': 'https://www.nytimes.com/2022/02/24/podcasts/the-daily/russian-invasion-ukraine-putin.html'}]},
#   'snippet': 'Feb 24, 2022 ... After months of escalating tensions, President '
#              'Vladimir V. Putin of Russia took to state television on Thursday '
#              'to declare the start of a\xa0...',
#   'title': 'The Russian Invasion Begins - The New York Times'},
#  {'displayLink': 'www.reuters.com',
#   'formattedUrl': 'https://www.reuters.com/.../us-officials-wont-confirm-reports-possible-russia- '
#                   'invasion-ukraine-wednesday-2022-02-13/',
#   'htmlFormattedUrl': 'https://www.reuters.com/.../us-officials-wont-confirm-reports-possible-<b>russia</b>- '
#                       '<b>invasion</b>-ukraine-wednesday-2022-02-13/',
#   'htmlSnippet': 'Feb 13, 2022 <b>...</b> White House National Security '
#                  'Adviser Jake Sullivan repeated that a <b>Russian '
#                  'invasion</b> could <b>begin</b> any day and President Joe '
#                  'Biden has said he&nbsp;...',
#   'htmlTitle': 'U.S. officials won&#39;t confirm reports on possible <b>Russia '
#                'invasion</b> of ...',
#   'kind': 'customsearch#result',
#   'link': 'https://www.reuters.com/world/europe/us-officials-wont-confirm-reports-possible-russia-invasion-ukraine-wednesday-2022-02-13/',
#   'pagemap': {'cse_image': [{'src': 'https://www.reuters.com/resizer/4Lgse9hESPkHydMvZPMwOZu3iS0=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/LUWOGIB3FFM7PCX5FIPGR2CM4I.jpg'}],
#               'cse_thumbnail': [{'height': '162',
#                                  'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQuugXqodmtqDwai-WKUY3DF3r_QcFs-kgzB9pEm3Soi4Zpvj2TsP9bUt8',
#                                  'width': '311'}],
#               'metatags': [{'ad:template': 'article',
#                             'analytics:ad_layout': 'leaderboard, right rail, '
#                                                    'sponsored',
#                             'analytics:page_layout': 'regular-article',
#                             'analyticsattributes.topicchannel': 'World',
#                             'analyticsattributes.topicsubchannel': 'Europe',
#                             'apple-itunes-app': 'app-id=602660809',
#                             'article:author': 'David Lawder,Katharine Jackson',
#                             'article:content_tier': 'metered',
#                             'article:modified_time': '2022-02-13T16:15:58.042Z',
#                             'article:published_time': '2022-02-13T16:15:29Z',
#                             'article:section': 'Europe',
#                             'article:tag': 'CWP,DEF,DIP,GEN,INTAG,NEWS1,POL,SECUR,WAR,WASH,CEEU,AMERS,US,EUROP,UA,RU,NASIA,NAMER,ASXPAC,CISC,EMRG,ASIA',
#                             'dcsext.channellist': 'World;',
#                             'dcsext.dartzone': '/4735792/reuters.com/world/europe/article',
#                             'fb:admins': '988502044532272',
#                             'fb:app_id': '988502044532272',
#                             'fb:pages': '114050161948682',
#                             'og:article:published_time': '2022-02-13T16:15:29Z',
#                             'og:description': 'Senior U.S. officials on Sunday '
#                                               'said they could not confirm '
#                                               'reports that U.S. intelligence '
#                                               'indicates that Russia is '
#                                               'planning to invade Ukraine on '
#                                               'Wednesday, but said they would '
#                                               'try to prevent any "surprise '
#                                               'attack" by sharing what they '
#                                               "knew of Russia's plans.",
#                             'og:image': 'https://www.reuters.com/resizer/4Lgse9hESPkHydMvZPMwOZu3iS0=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/LUWOGIB3FFM7PCX5FIPGR2CM4I.jpg',
#                             'og:locale': 'en_US',
#                             'og:locale:alternate': 'jp_JP',
#                             'og:site_name': 'Reuters',
#                             'og:title': "U.S. officials won't confirm reports "
#                                         'on possible Russia invasion of '
#                                         'Ukraine on Wednesday',
#                             'og:type': 'article',
#                             'og:url': 'https://www.reuters.com/world/europe/us-officials-wont-confirm-reports-possible-russia-invasion-ukraine-wednesday-2022-02-13/',
#                             'twitter:card': 'summary_large_image',
#                             'twitter:creator': '@Reuters',
#                             'twitter:description': 'Senior U.S. officials on '
#                                                    'Sunday said they could not '
#                                                    'confirm reports that U.S. '
#                                                    'intelligence indicates '
#                                                    'that Russia is planning to '
#                                                    'invade Ukraine on '
#                                                    'Wednesday, but said they '
#                                                    'would try to prevent any '
#                                                    '"surprise attack" by '
#                                                    'sharing what they knew of '
#                                                    "Russia's plans.",
#                             'twitter:image': 'https://www.reuters.com/resizer/4Lgse9hESPkHydMvZPMwOZu3iS0=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/LUWOGIB3FFM7PCX5FIPGR2CM4I.jpg',
#                             'twitter:image:alt': 'Ukrainian service members '
#                                                  'walk with M141 Bunker Defeat '
#                                                  'Munition weapons supplied by '
#                                                  'the United States during '
#                                                  'drills at the International '
#                                                  'Peacekeeping Security Centre '
#                                                  'near Yavoriv in the Lviv '
#                                                  'region, Ukraine, February 4, '
#                                                  '2022. REUTERS/Roman '
#                                                  'Baluk/File Photo',
#                             'twitter:site': '@Reuters',
#                             'twitter:title': "U.S. officials won't confirm "
#                                              'reports on possible Russia '
#                                              'invasion of Ukraine on Wednesday',
#                             'viewport': 'width=device-width, '
#                                         'initial-scale=1'}]},
#   'snippet': 'Feb 13, 2022 ... White House National Security Adviser Jake '
#              'Sullivan repeated that a Russian invasion could begin any day '
#              'and President Joe Biden has said he\xa0...',
#   'title': "U.S. officials won't confirm reports on possible Russia invasion "
#            'of ...'},
#  {'displayLink': 'www.cnn.com',
#   'formattedUrl': 'https://www.cnn.com/...russia.../h_efaa0d529edb3c122cc17b3968d6d211',
#   'htmlFormattedUrl': 'https://www.cnn.com/...<b>russia</b>.../h_efaa0d529edb3c122cc17b3968d6d211',
#   'htmlSnippet': 'Feb 26, 2022 <b>...</b> Around 100,000 people have entered '
#                  'Poland from Ukraine since the <b>start</b> of '
#                  '<b>Russia&#39;s invasion</b> of the country on Thursday, a '
#                  'Polish border&nbsp;...',
#   'htmlTitle': '(70) 100,000 Ukrainian refugees have arrived since '
#                '<b>start</b> of <b>Russian</b> ...',
#   'kind': 'customsearch#result',
#   'link': 'https://www.cnn.com/europe/live-news/ukraine-russia-news-02-26-22/h_efaa0d529edb3c122cc17b3968d6d211',
#   'pagemap': {'LiveBlogPosting': [{}],
#               'VideoObject': [{}],
#               'cse_image': [{'src': 'https://cdn.cnn.com/cnnnext/dam/assets/220225095200-ukraine-russia-conflict-022522-super-tease.jpg'}],
#               'cse_thumbnail': [{'height': '168',
#                                  'src': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcSpWJrMQtHTc-CXCQtQdO9oFCpcBIpLHyU-3AfFSR9RtUaCgkaWs1iQX9Q',
#                                  'width': '299'}],
#               'metatags': [{'author': 'By <a '
#                                       'href="/profiles/adrienne-vogt">Adrienne '
#                                       'Vogt</a>, <a '
#                                       'href="/profiles/lauren-moorhouse">Lauren '
#                                       'Said-Moorhouse</a>, Jeevan Ravindran, '
#                                       '<a '
#                                       'href="/profiles/peter-wilkinson">Peter '
#                                       'Wilkinson</a>, <a '
#                                       'href="/profiles/jessie-yeung">Jessie '
#                                       'Yeung</a>, <a '
#                                       'href="/profiles/brad-lendon">Brad '
#                                       'Lendon</a>, <a '
#                                       'href="/profiles/steve-george">Steve '
#                                       'George</a>, <a '
#                                       'href="/profiles/meg-wagner">Meg '
#                                       'Wagner</a>, <a '
#                                       'href="/profiles/amir-vera">Amir '
#                                       'Vera</a> and <a '
#                                       'href="/profiles/helen-regan">Helen '
#                                       'Regan</a>, CNN',
#                             'fb:app_id': '80401312489',
#                             'fb:pages': '5550296508,18793419640',
#                             'lastmod': '2022-02-26T11:29:37Z',
#                             'og:author': 'By <a '
#                                          'href="/profiles/adrienne-vogt">Adrienne '
#                                          'Vogt</a>, <a '
#                                          'href="/profiles/lauren-moorhouse">Lauren '
#                                          'Said-Moorhouse</a>, Jeevan '
#                                          'Ravindran, <a '
#                                          'href="/profiles/peter-wilkinson">Peter '
#                                          'Wilkinson</a>, <a '
#                                          'href="/profiles/jessie-yeung">Jessie '
#                                          'Yeung</a>, <a '
#                                          'href="/profiles/brad-lendon">Brad '
#                                          'Lendon</a>, <a '
#                                          'href="/profiles/steve-george">Steve '
#                                          'George</a>, <a '
#                                          'href="/profiles/meg-wagner">Meg '
#                                          'Wagner</a>, <a '
#                                          'href="/profiles/amir-vera">Amir '
#                                          'Vera</a> and <a '
#                                          'href="/profiles/helen-regan">Helen '
#                                          'Regan</a>, CNN',
#                             'og:description': 'Around 100,000 people have '
#                                               'entered Poland from Ukraine '
#                                               'since the start of Russia’s '
#                                               'invasion of the country on '
#                                               'Thursday, a Polish border guard '
#                                               'said Saturday.',
#                             'og:image': 'https://cdn.cnn.com/cnnnext/dam/assets/220225095200-ukraine-russia-conflict-022522-super-tease.jpg',
#                             'og:image:alt': 'CNN - February 26, 2022 '
#                                             'Russia-Ukraine news',
#                             'og:image:height': '619',
#                             'og:image:width': '1100',
#                             'og:site_name': 'CNN',
#                             'og:title': 'February 26, 2022 Russia-Ukraine news',
#                             'og:type': 'article',
#                             'og:url': 'https://www.cnn.com/europe/live-news/ukraine-russia-news-02-26-22/index.html',
#                             'pubdate': '2022-02-26T05:01:12Z',
#                             'section': 'europe',
#                             'twitter:card': 'summary_large_image',
#                             'twitter:description': 'Russian President Vladimir '
#                                                    'Putin announced a military '
#                                                    'operation in Ukraine early '
#                                                    'Thursday.  A battle is '
#                                                    'underway for control of '
#                                                    "Ukraine's capital, Kyiv. "
#                                                    'The US has warned Russia '
#                                                    'is seeking to encircle the '
#                                                    'city, and a Ukrainian '
#                                                    'official said it has been '
#                                                    'hit by missiles. Follow '
#                                                    'here for live news updates '
#                                                    'from the ground in '
#                                                    'Ukraine.',
#                             'twitter:image': 'https://cdn.cnn.com/cnnnext/dam/assets/220225095200-ukraine-russia-conflict-022522-super-tease.jpg',
#                             'twitter:image:alt': 'February 26, 2022 '
#                                                  'Russia-Ukraine news',
#                             'twitter:title': 'February 26, 2022 Russia-Ukraine '
#                                              'news',
#                             'viewport': 'width=device-width, '
#                                         'initial-scale=1'}]},
#   'snippet': 'Feb 26, 2022 ... Around 100,000 people have entered Poland from '
#              "Ukraine since the start of Russia's invasion of the country on "
#              'Thursday, a Polish border\xa0...',
#   'title': '(70) 100,000 Ukrainian refugees have arrived since start of '
#            'Russian ...'}]
